# %%
E = EllipticCurve("389.a1")
print(E)
N = E.conductor()
print("Conductor", N)
L = E.lseries().dokchitser(algorithm='gp')
print(L)
# Out:
# Elliptic Curve defined by y^2 + y = x^3 + x^2 - 2*x over Rational Field
# Conductor 389
# Dokchitser L-function associated to Elliptic Curve defined by y^2 + y = x^3 + x^2 - 2*x over Rational Field

# %%
m = lambda z: sum(an * z^(n) for n, an in enumerate(E.anlist(2000)[1:]))
M = lambda z: sum(an * z^(n) / (n + 1) for n, an in enumerate(E.anlist(2000)[1:]))

# %%
fm = lambda n, z: 1/n * sum(m(CC(z*exp(2*pi*I/n * i))) for i in range(0, n))

# %%
fm(4, 0.5)
# Out:
# 0.815592029944020

# %%
fm(389, 0.5)
# Out:
# 1.00000000000000 - 8.36591578645884e-18*I

# %%
data = [(n, fm(n, 0.5)) for n in range(1, 100)]

# %%
scatter_plot([(n, abs(x)) for n, x in data])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(lambda z: abs(fm(4, z)), -0.9, 0.9)
# Out:
# Graphics object consisting of 1 graphics primitive
