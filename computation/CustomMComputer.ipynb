# %%
def cTransform(z):
    return exp(4*pi^2/N * 1/log(z))

# %%
E = EllipticCurve("389.a1")
print(E)
N = E.conductor()
print(N)
anlist = E.anlist(2000)[1:]
# Out:
# Elliptic Curve defined by y^2 + y = x^3 + x^2 - 2*x over Rational Field
# 389

# %%
m = lambda z: sum(an * z^(n) for n, an in enumerate(anlist))

# %%
def compute_m_experimental(z):
    z1 = cTransform(z)
    return 4*pi^2 / N * log(z)^(-2) * z1/z * m(CC(z1))

# %%
m(.5)
# Out:
# -0.380213368395602

# %%
CC(compute_m_experimental(.5))
# Out:
# -0.380213368395601

# %%
m(-.5)
# Out:
# 0.848103718237843

# %%
CC(compute_m_experimental(-.5))
# Out:
# 0.848114879440495 + 4.00949662556763e-6*I

# %%
m(.98)
# Out:
# 1.64787069901854

# %%
CC(compute_m_experimental(.98))
# Out:
# 1.64787069901741

# %%
CC(cTransform(.98))
# Out:
# 0.00658189612444460

# %%
plot(cTransform, 0, 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(lambda x: cTransform(x).real_part(), -1, 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(lambda x: cTransform(x).imag_part(), -1, 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
CC(cTransform(-1))
# Out:
# 0.999478261648754 - 0.0322986763132106*I

# %%
CC(cTransform(I))
# Out:
# 0.997913591016829 - 0.0645636497101671*I

# %%
plot(lambda x: arg(cTransform(exp(x * I))), 0, 2*pi)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(lambda x: cTransform(exp(x * I)).imag_part(), 0, 2*pi)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(lambda x: cTransform(exp(x * I)).real_part(), 0, 2*pi)
# Out:
# Graphics object consisting of 1 graphics primitive
